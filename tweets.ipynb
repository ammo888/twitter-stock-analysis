# %%
import pandas as pd

# %%
tweets = pd.read_csv('tweets.csv')

# %%
tweets
# Out:
#                       id      conversation_id  \
# 0    1574236309555748866  1574236309555748866
# 1    1574236246284460033  1573024785940062213
# 2    1574236204777996288  1574112663864430593
# 3    1574236186888970241  1574112076435521540
# 4    1574236177154150401  1574174172258836480
# ..                   ...                  ...
# 844  1574221879027847168  1573356786941587457
# 845  1574221860694212609  1574112663864430593
# 846  1574221855015190528  1574135897590616064
# 847  1574221830549708801  1574221830549708801
# 848  1574221825839603720   922168727457513472
#
#      referenced_tweets.replied_to.id  referenced_tweets.retweeted.id  \
# 0                                NaN                             NaN
# 1                       1.573048e+18                             NaN
# 2                       1.574228e+18                             NaN
# 3                       1.574112e+18                             NaN
# ...
